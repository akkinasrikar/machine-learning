# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use("fivethirtyeight")
import warnings
warnings.filterwarnings("ignore")
import plotly.graph_objects as go
import plotly.express as px
from sklearn.datasets import load_breast_cancer

# %%
dataset=load_breast_cancer()

# %%
breast_cancer=pd.DataFrame(dataset.data,columns=dataset.feature_names)

# %%
breast_cancer["target"]=dataset.target

# %%
breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
breast_cancer.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
breast_cancer.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
plt.figure(figsize=(25,12.5))
sns.heatmap(breast_cancer.corr(),annot=True,yticklabels=False,cmap="GnBu_r")

# %%
plt.figure(figsize=(23,12.5))
sns.clustermap(breast_cancer.corr(),cmap="vlag")

# %%
plt.figure(figsize=(10,6))
sns.countplot(breast_cancer["target"])

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y="mean radius",x="target",data=breast_cancer,hue="target")
plt.figure(figsize=(10,6))
sns.boxenplot(y="mean radius",x="target",data=breast_cancer,hue="target",scale="linear")
plt.figure(figsize=(10,6))
sns.violinplot(y="mean radius",x="target",data=breast_cancer,hue="target")
plt.figure(figsize=(10,6))
sns.swarmplot(y="mean radius",x="target",data=breast_cancer,hue="target")
plt.figure(figsize=(10,6))
sns.kdeplot(breast_cancer["mean radius"],breast_cancer["target"])
plt.figure(figsize=(10,6))
sns.kdeplot(breast_cancer["mean radius"],breast_cancer["target"],color="g",shade=True)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="target",y="mean radius",data=breast_cancer)

# %%
from sklearn.naive_bayes import  MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
x=breast_cancer.drop(["target"],axis=1)
y=breast_cancer["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=32)

# %%
nb=MultinomialNB()
knn=KNeighborsClassifier(n_neighbors=5)
lg=LogisticRegression()
dc=DecisionTreeClassifier()
rnf=RandomForestClassifier()
sv=SVC(C=100, degree=1,gamma=0.1,kernel='rbf')

voting_clf=VotingClassifier(estimators=[('lr',lg),
                                        ('rf',rnf),
                                        ('dt',dc),
                                        ('kn',knn),
                                        ('nby',nb),
                                        ('svm',sv)],voting='hard')
voting_clf.fit(x_train,y_train)
y_pred_v=voting_clf.predict(x_test)
print("voting classifier")
print(accuracy_score(y_test,y_pred_v))
# Out:
# voting classifier
# 0.9440559440559441

# %%
print(confusion_matrix(y_test,y_pred_v))
print(classification_report(y_test,y_pred_v))
# Out:
# [[50  6]
#  [ 2 85]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93        56
#            1       0.93      0.98      0.96        87
#
#     accuracy                           0.94       143
#    macro avg       0.95      0.93      0.94       143
# weighted avg       0.94      0.94      0.94       143

# %%
for clf in (nb,knn,lg,dc,rnf,sv):
    clf.fit(x_train,y_train)
    y_pred=clf.predict(x_test)
    print(clf.__class__.__name__,accuracy_score(y_test,y_pred))
# Out:
# MultinomialNB 0.8671328671328671
# KNeighborsClassifier 0.8951048951048951
# LogisticRegression 0.9230769230769231
# DecisionTreeClassifier 0.9370629370629371
# RandomForestClassifier 0.958041958041958
# SVC 0.6083916083916084
